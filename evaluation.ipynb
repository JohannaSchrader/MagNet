# %% [markdown]
# # Imports

# %%
from evaluation_functions import *
# Out:
# 2026-03-28 19:13:57.208966: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/schrader/micromamba/envs/magnet_test/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# ...

# %% [markdown]
# ## Fig. 4. Cleveland dot plot

# %%
plot_clevelant()

# %% [markdown]
# ### Fig. 7. Demographic Performance Evaluation

# %%
plot_sex_age_stage_grade()
# Out:
# task 14-Class (Tissue) results missing
# --- Original Performance (All Classes) ---
# Task: 19-Class (Disease) | Sex: Female | F1: 0.744 ± 0.019
# Task: 19-Class (Disease) | Sex: Male | F1: 0.876 ± 0.026

# %% [markdown]
# ### Fig. 8. Diagnostic Confusion and Sex-Specific Performance Ablation

# %%
plot_sex_ablation_panel()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_sex_ablation_panel()
#
# File ~/MagNet/evaluation_functions.py:410, in plot_sex_ablation_panel()
#     408 for comb, task_name in tasks_map.items():
#     409     pred_file = os.path.join("result", "baselines", f"{DATASET_NAME}_nestedcv_predictions_{comb}_OURS.csv")
# --> 410     df = pd.read_csv(pred_file)
#     411     df['Real_ID'] = df['id'].apply(lambda row_idx: str(accessions[int(row_idx)]).strip())
#     412     df = df.merge(status[['Accession', 'sex']], left_on='Real_ID', right_on='Accession', how='left')
#
# ...

# %% [markdown]
# ### Fig. 9. Diagnostic Confusion by Solid Tumor Stage. Norma

# %%
plot_confusion_by_stage()

# %% [markdown]
# ### Fig. 5. Out-of-Distribution Robustness.

# %%
plot_ood()
# Out:
#   [Warning] Skipping MLP: File not found
#   [Warning] Skipping TABNET: File not found
#   [Warning] Skipping HEAD: File not found
#   [Warning] Skipping 1D: File not found
#   [Warning] Skipping XGB: File not found
#   [Warning] Skipping RF: File not found
#   [Warning] Skipping LR: File not found
# /home/schrader/MagNet/evaluation_functions.py:677: UserWarning: The palette list has more values (8) than needed (1), which may not be intended.
#   sns.barplot(
# /home/schrader/MagNet/evaluation_functions.py:677: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1.5}` instead.
#
#   sns.barplot(
# /home/schrader/MagNet/evaluation_functions.py:687: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(SCALE_LABELS)
# ...

# %% [markdown]
# ### Fig. 6. Bounded Latent Manifold and Diagnostic Performance.

# %%
plot_interpret()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774721679.548443 1269808 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:c1:00.0, compute capability: 8.0
# I0000 00:00:1774721679.549673 1269808 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 79193 MB memory:  -> device: 1, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:e1:00.0, compute capability: 8.0
# 2026-03-28 19:14:41.489655: I external/local_xla/xla/service/service.cc:163] XLA service 0x14d8f40042f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-03-28 19:14:41.489689: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA A100 80GB PCIe, Compute Capability 8.0
# ...

# %% [markdown]
# ### Fig. 3. Dataset Overview and Inherent Complexity.

# %%
plot_dataset_overview()

# %%
plot_latex_table()
# Out:
# \begin{table*}[t]
#     \centering
#     \caption{Multiclass Diagnostic Performance on Serum miRNA across baselines. Metrics are presented as Mean $\pm$ Standard Deviation across the 5 outer test folds. Best results in \textbf{bold} and second best results \underline{underlined}.}
#     \label{tab:performance}
#     \setlength{\tabcolsep}{4pt} % Compress columns slightly to fit \pm
#     \begin{tabular}{@{}lcccccc@{}}
#     \toprule
#     & \multicolumn{3}{c}{\textbf{Tissue-of-Origin (14 Classes)}} & \multicolumn{3}{c}{\textbf{Disease (19 Classes)}} \\
#     \cmidrule(lr){2-4} \cmidrule(l){5-7}
#     \textbf{Model} & \textbf{Macro F1} & \textbf{Bal. Acc} & \textbf{AUROC} & \textbf{Macro F1} & \textbf{Bal. Acc} & \textbf{AUROC} \\
#     \midrule
#     Logistic Regression & --- & --- & --- & --- & --- & --- \\
#     Random Forest & --- & --- & --- & --- & --- & --- \\
#     XGBoost & --- & --- & --- & --- & --- & --- \\
#     1D-CNN & --- & --- & --- & --- & --- & --- \\
# ...
